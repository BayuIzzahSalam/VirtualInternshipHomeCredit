# %%
import pandas as pd

# %%
df = pd.read_csv('Marketing_Campaign_Data_A-21492758-f47a-4913-971e-68c9a721311a.csv')

# %%
df
# Out:
#        Unnamed: 0  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           58785       0         Cash loans           F            Y
# 1          166116       0         Cash loans           F            N
# 2          170111       0         Cash loans           F            Y
# 3          184247       0         Cash loans           F            N
# 4           75886       0         Cash loans           M            Y
# ...           ...     ...                ...         ...          ...
# 30717      183150       1         Cash loans           F            N
# 30718      192611       0         Cash loans           F            N
# 30719       50975       0         Cash loans           F            Y
# 30720       71489       0         Cash loans           F            N
# 30721       96406       0         Cash loans           F            Y
#
#       FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                       int64
# TARGET                           int64
# NAME_CONTRACT_TYPE              object
# CODE_GENDER                     object
# FLAG_OWN_CAR                    object
# FLAG_OWN_REALTY                 object
# AMT_INCOME_TOTAL               float64
# AMT_CREDIT                     float64
# AMT_ANNUITY                    float64
# AMT_GOODS_PRICE                float64
# NAME_EDUCATION_TYPE             object
# NAME_HOUSING_TYPE               object
# REGION_POPULATION_RELATIVE     float64
# REGION_RATING_CLIENT_W_CITY      int64
# APPL_DATETIME                   object
# DATE_BIRTH                      object
# dtype: object

# %%
df['DATE_BIRTH'] = pd.to_datetime(df['DATE_BIRTH'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30722 entries, 0 to 30721
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   30722 non-null  int64
#  1   TARGET                       30722 non-null  int64
#  2   NAME_CONTRACT_TYPE           30722 non-null  object
#  3   CODE_GENDER                  30722 non-null  object
#  4   FLAG_OWN_CAR                 30722 non-null  object
#  5   FLAG_OWN_REALTY              30722 non-null  object
#  6   AMT_INCOME_TOTAL             30722 non-null  float64
#  7   AMT_CREDIT                   30722 non-null  float64
#  8   AMT_ANNUITY                  30722 non-null  float64
#  9   AMT_GOODS_PRICE              30722 non-null  float64
#  10  NAME_EDUCATION_TYPE          30722 non-null  object
#  11  NAME_HOUSING_TYPE            30722 non-null  object
# ...

# %%
from datetime import date

# %%
yearBirth = []
for index, row in df.iterrows():
    yearBirth.append(row['DATE_BIRTH'].year)

# %%
age = []
for x in yearBirth :
    string = str(x)
    integer = int(string)
    age1 = date.today().year - integer
    age.append(age1)

# %%
print(age)
# Out:
# [63, 71, 43, 64, 37, 32, 51, 71, 75, 29, 33, 69, 52, 63, 75, 43, 50, 27, 64, 36, 67, 73, 57, 67, 55, 29, 29, 55, 63, 68, 67, 39, 40, 61, 70, 64, 67, 66, 55, 64, 29, 55, 32, 30, 49, 61, 71, 41, 72, 71, 65, 61, 63, 45, 44, 37, 71, 61, 59, 35, 59, 40, 72, 36, 59, 26, 31, 65, 50, 40, 35, 32, 52, 72, 30, 31, 59, 71, 70, 45, 53, 59, 62, 55, 62, 44, 67, 39, 44, 70, 56, 66, 62, 70, 45, 56, 63, 65, 36, 30, 26, 48, 41, 27, 68, 28, 66, 70, 28, 66, 39, 61, 32, 65, 56, 60, 60, 63, 59, 61, 54, 63, 71, 32, 59, 67, 62, 71, 55, 56, 62, 38, 31, 31, 75, 46, 71, 38, 65, 61, 69, 49, 62, 36, 43, 60, 58, 69, 63, 58, 43, 64, 72, 30, 62, 55, 36, 49, 40, 42, 58, 41, 33, 29, 63, 48, 30, 33, 49, 72, 68, 51, 72, 70, 47, 58, 61, 72, 59, 70, 40, 73, 43, 53, 30, 35, 68, 73, 62, 60, 63, 62, 49, 33, 56, 69, 60, 72, 43, 70, 69, 30, 61, 53, 59, 30, 46, 70, 57, 38, 70, 63, 70, 33, 70, 48, 32, 75, 52, 61, 50, 59, 71, 56, 72, 60, 61, 59, 62, 35, 43, 36, 71, 72, 49, 59, 65, 38, 70, 36, 60, 38, 66, 34, 59, 71, 32, 35, 42, 7
# ...

# %%
lateTen = []
for i in age:
    if i < 20:
        lateTen.append(i)
        
print(sum(lateTen))
# Out:
# 0

# %%
twenty = []
for i in age:
    if i > 20 and i < 30:
        twenty.append(i)
        
print(len(twenty))
# Out:
# 2031

# %%
thirty = []
for i in age:
    if i > 30 and i < 40:
        thirty.append(i)
        
print(len(thirty))
# Out:
# 4947

# %%
fourty = []
for i in age:
    if i > 40 and i < 50:
        fourty.append(i)
        
print(len(fourty))
# Out:
# 3596

# %%
fifty = []
for i in age:
    if i > 50 and i < 60:
        fifty.append(i)
        
print(len(fifty))
# Out:
# 4866

# %%
aboveSixty = []
for i in age:
    if i > 60:
        aboveSixty.append(i)
        
print(len(aboveSixty))
# Out:
# 12639
